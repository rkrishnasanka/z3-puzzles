# %%
from z3 import *

# %% [markdown]
# ![0dfe6a32-6a61-4617-9557-e90cda92a04f.JPG](attachment:0dfe6a32-6a61-4617-9557-e90cda92a04f.JPG)

# %%
popcorn, reel, bucket = Ints('popcorn reel bucket')
s = Solver()
s.add(3*bucket == 30)
s.add(bucket + 2*reel == 18)
s.add(reel + 2*popcorn == 10)
s.check()
# Out:
# sat

# %%
m = s.model()
m.evaluate(reel + bucket + popcorn)
# Out:
# 17
